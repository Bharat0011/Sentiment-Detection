# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1./255 )

val_data = val_datagen.flow_from_directory(directory= "train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 350 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model2.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[mc])
# Out:
# C:\Users\choudhary_b\AppData\Local\Temp\ipykernel_2500\1643128203.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_data,
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9937
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to best_model2.h5
# 10/10 [==============================] - 9s 878ms/step - loss: 0.0298 - accuracy: 0.9937 - val_loss: 3.8485e-05 - val_accuracy: 1.0000
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9874
# Epoch 2: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 882ms/step - loss: 0.0504 - accuracy: 0.9874 - val_loss: 2.1312e-06 - val_accuracy: 1.0000
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9874
# Epoch 3: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 9s 958ms/step - loss: 0.0486 - accuracy: 0.9874 - val_loss: 0.0211 - val_accuracy: 0.9883
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9748
# Epoch 4: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0901 - accuracy: 0.9748 - val_loss: 0.0721 - val_accuracy: 0.9727
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9811
# Epoch 5: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.1157 - accuracy: 0.9811 - val_loss: 0.0522 - val_accuracy: 0.9883
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9843
# Epoch 6: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0628 - accuracy: 0.9843 - val_loss: 5.1761e-04 - val_accuracy: 1.0000
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0633 - accuracy: 0.9811
# Epoch 7: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 998ms/step - loss: 0.0633 - accuracy: 0.9811 - val_loss: 0.0458 - val_accuracy: 0.9883
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9811
# Epoch 8: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.1269 - accuracy: 0.9811 - val_loss: 0.1247 - val_accuracy: 0.9805
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9780
# Epoch 9: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.1372 - accuracy: 0.9780 - val_loss: 0.0792 - val_accuracy: 0.9922
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9874
# Epoch 10: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0956 - accuracy: 0.9874 - val_loss: 0.0109 - val_accuracy: 0.9961
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0966 - accuracy: 0.9844
# Epoch 11: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 997ms/step - loss: 0.0966 - accuracy: 0.9844 - val_loss: 0.0087 - val_accuracy: 0.9961
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9937
# Epoch 12: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 998ms/step - loss: 0.0220 - accuracy: 0.9937 - val_loss: 0.0069 - val_accuracy: 0.9961
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9906
# Epoch 13: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.1432 - accuracy: 0.9906 - val_loss: 0.0134 - val_accuracy: 0.9961
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9906
# Epoch 14: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0350 - accuracy: 0.9906 - val_loss: 0.0158 - val_accuracy: 0.9961
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0115 - accuracy: 0.9969
# Epoch 15: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0115 - accuracy: 0.9969 - val_loss: 2.1256e-04 - val_accuracy: 1.0000
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 16: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 17/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9874
# Epoch 17: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0266 - accuracy: 0.9874 - val_loss: 5.1199e-06 - val_accuracy: 1.0000
# Epoch 18/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9874
# Epoch 18: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 993ms/step - loss: 0.0182 - accuracy: 0.9874 - val_loss: 8.8984e-07 - val_accuracy: 1.0000
# Epoch 19/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9969
# Epoch 19: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 995ms/step - loss: 0.0044 - accuracy: 0.9969 - val_loss: 2.4982e-06 - val_accuracy: 1.0000
# Epoch 20/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9969
# Epoch 20: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0034 - accuracy: 0.9969 - val_loss: 1.2141e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0461 - accuracy: 0.9969
# Epoch 21: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0461 - accuracy: 0.9969 - val_loss: 1.0495e-05 - val_accuracy: 1.0000
# Epoch 22/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9969
# Epoch 22: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0397 - accuracy: 0.9969 - val_loss: 5.2272e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9906
# Epoch 23: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0429 - accuracy: 0.9906 - val_loss: 0.0087 - val_accuracy: 0.9961
# Epoch 24/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.9874
# Epoch 24: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0447 - accuracy: 0.9874 - val_loss: 0.0343 - val_accuracy: 0.9922
# Epoch 25/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0543 - accuracy: 0.9874
# Epoch 25: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0543 - accuracy: 0.9874 - val_loss: 0.0527 - val_accuracy: 0.9922
# Epoch 26/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9937
# Epoch 26: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0311 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9961
# Epoch 27/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9811
# Epoch 27: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 11s 1s/step - loss: 0.0885 - accuracy: 0.9811 - val_loss: 0.0441 - val_accuracy: 0.9922
# Epoch 28/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0664 - accuracy: 0.9874
# Epoch 28: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0664 - accuracy: 0.9874 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 29/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9906
# Epoch 29: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 1s/step - loss: 0.0572 - accuracy: 0.9906 - val_loss: 1.8900e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9843
# Epoch 30: val_accuracy did not improve from 1.00000
# 10/10 [==============================] - 10s 999ms/step - loss: 0.1174 - accuracy: 0.9843 - val_loss: 0.0274 - val_accuracy: 0.9961

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("best_model2.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "train/happy/download (2).jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 43ms/step
#  the image is of Happy
